# %% [markdown]
# # TASK--1

# %% [markdown]
# ![SURAJ.jpg](attachment:10dab886-e373-456d-b267-2d9650ea9715.jpg)

# %% [markdown]
# # **CH SURAJ SUBUDHI**

# %% [markdown]
# # **PREDICTION USING SUPERVISED ML**

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %% [markdown]
# **Importing DataSet**

# %%
df=pd.read_csv('../input/hours-and-scores/score_prediction.csv')
print('First Five Rows....')
df.head(5)
# Out:
# First Five Rows....
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# **EDA TO GAIN INSIGHTSFROM THE DATA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %% [markdown]
# **Positive Linear Regression**

# %%
Hours=df['Hours']
Score=df['Scores']
plt.scatter(Hours,Score,color='green',marker='x')
plt.title('Hours vs Scores')
plt.xlabel('Hours')
plt.ylabel('Secured Scores')
plt.show()

# %% [markdown]
# **Determine the training and testing datasets...**

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# **Model Selection and Training**

# %%
model=linear_model.LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0],model.intercept_
# Out:
# (9.91065648064224, 2.018160041434662)

# %% [markdown]
# **Linear Regression Line**

# %%
line=model.coef_[0]*x + model.intercept_
plt.scatter(x,y,marker='x',color='green',label='True')
plt.plot(x,line,color='red',label='Predicted')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Scores Vs Hours')
plt.legend()
plt.show()

# %% [markdown]
# **Determine R Square Score**

# %%
y_prediction=model.predict(x_test)

print('R2 score :{:^.4f}'.format(r2_score(y_test,y_prediction)))
print('RMSE :{:^.4f}'.format(mean_squared_error(y_test,y_prediction,squared=False)))
print('MAE :{:^.4f}'.format(mean_absolute_error(y_test,y_prediction)))
# Out:
# R2 score :0.9455
# RMSE :4.6474
# MAE :4.1839

# %% [markdown]
# **Dataframe about Actual and Prediction**

# %%
df2=pd.DataFrame({'Actual':y_test,'Prediction':y_prediction})
df2
# Out:
#    Actual  Prediction
# 0      20   16.884145
# 1      27   33.732261
# 2      69   75.357018
# 3      30   26.794801
# 4      62   60.491033

# %% [markdown]
# **Predict The Score If a Student Studies 9.25hours/Day**

# %%
hours=9.25
print('No Of Hours::',hours)
print('Predicted Score::',model.predict([[hours]])[0])
# Out:
# No Of Hours:: 9.25
# Predicted Score:: 93.69173248737539

# %% [markdown]
# Answer:-If a student studies 9.25 hours/day then his/her predicted score is 93.7..

# %% [markdown]
# ****
